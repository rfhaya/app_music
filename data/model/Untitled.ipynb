# %%
from joblib import load

# Membaca model
model = load('genre/data_by_genre.pkl')
model
# Out:
#                                     artists  \
# 0                    [Sam Smith;Kim Petras]
# 1                        [Bizarrap;Quevedo]
# 2                 [David Guetta;Bebe Rexha]
# 3                           [Manuel Turizo]
# 4                               [Bad Bunny]
# ...                                     ...
# 73603                          [Neon Trees]
# 73604                           [Gabrielle]
# 73605  [The English Concert;Trevor Pinnock]
# 73606                          [Joss Stone]
# 73607                   [Fabrizio De André]
#
#                                               track_name  popularity  \
# 0                              Unholy (feat. Kim Petras)         100
# 1                  Quevedo: Bzrp Music Sessions, Vol. 52          99
# 2                                        I'm Good (Blue)          98
# 3                                             La Bachata          98
# 4                                       Tití Me Preguntó          97
# ...
